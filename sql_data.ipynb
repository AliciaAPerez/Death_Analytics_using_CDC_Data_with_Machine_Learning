# %%
# Ignore SQLITE warnings related to Decimal numbers in the Chinook database
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
from collections import OrderedDict
import pandas as pd 
import collections
import json

# %%
import pandas as pd
import matplotlib.pyplot as plt
from config import USER, PASSWORD, ADDRESS, PORT, DATABASE
from sqlalchemy import create_engine
connection_string = (f'postgresql://{USER}:{PASSWORD}@{ADDRESS}:{PORT}/{DATABASE}')

# %%
engine = create_engine(connection_string)
cn = engine.connect()

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['cdc_death_table', 'life_expectancy', 'un_data', 'leading_causes_death']

# %%
deaths=Base.classes.leading_causes_death

# %%
session = Session(engine)

# %%
deaths_dt=session.query(deaths.cause).all()[0]
deaths_dt
# Out:
# ('Accidents (unintentional injuries) (V01-X59,Y85-Y86)')

# %%
data = session.query(deaths).all()
load = []
content = {}
for result in data:
        content = {'year': result.year, 
                   'cause': result.cause, 
                   'cause_name': result.cause_name,
                   'state': result.state,
                   'deaths': result.deaths,
                   'age_adjusted_death_rate': result.age_adjusted_death_rate
                  }
                
        load.append(content)

load
# Out:
# [{'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Alabama',
#   'deaths': '2,313',
#   'age_adjusted_death_rate': '52.2'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Alaska',
#   'deaths': '294',
#   'age_adjusted_death_rate': '55.9'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Arizona',
#   'deaths': '2,214',
#   'age_adjusted_death_rate': '44.8'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Arkansas',
#   'deaths': '1,287',
#   'age_adjusted_death_rate': '47.6'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'California',
#   'deaths': '9,198',
#   'age_adjusted_death_rate': '28.7'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Colorado',
#   'deaths': '1,519',
#   'age_adjusted_death_rate': '39'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Connecticut',
#   'deaths': '1,034',
#   'age_adjusted_death_rate': '29.3'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Delaware',
#   'deaths': '267',
#   'age_adjusted_death_rate': '35.3'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'District of Columbia',
#   'deaths': '161',
#   'age_adjusted_death_rate': '28.4'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Florida',
#   'deaths': '5,961',
#   'age_adjusted_death_rate': '35.7'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Georgia',
#   'deaths': '3,078',
#   'age_adjusted_death_rate': '41.5'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Hawaii',
#   'deaths': '293',
#   'age_adjusted_death_rate': '24.3'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Idaho',
#   'deaths': '597',
#   'age_adjusted_death_rate': '48.3'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Illinois',
#   'deaths': '4,125',
#   'age_adjusted_death_rate': '33.7'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Indiana',
#   'deaths': '2,309',
#   'age_adjusted_death_rate': '38.4'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Iowa',
#   'deaths': '1,123',
#   'age_adjusted_death_rate': '35.2'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Kansas',
#   'deaths': '1,126',
#   'age_adjusted_death_rate': '40.7'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Kentucky',
#   'deaths': '1,730',
#   'age_adjusted_death_rate': '43.3'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Louisiana',
#   'deaths': '1,940',
#   'age_adjusted_death_rate': '44.7'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Maine',
#   'deaths': '458',
#   'age_adjusted_death_rate': '34.9'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Maryland',
#   'deaths': '1,296',
#   'age_adjusted_death_rate': '25.9'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Montana',
#   'deaths': '8,128',
#   'age_adjusted_death_rate': '857.6'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Massachusetts',
#   'deaths': '1,303',
#   'age_adjusted_death_rate': '19.6'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Michigan',
#   'deaths': '3,188',
#   'age_adjusted_death_rate': '32.8'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Minnesota',
#   'deaths': '1,772',
#   'age_adjusted_death_rate': '35.8'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Mississippi',
#   'deaths': '1,642',
#   'age_adjusted_death_rate': '58.9'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Missouri',
#   'deaths': '2,465',
#   'age_adjusted_death_rate': '43.2'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Montana',
#   'deaths': '461',
#   'age_adjusted_death_rate': '50.3'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Nebraska',
#   'deaths': '668',
#   'age_adjusted_death_rate': '37.3'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Nevada',
#   'deaths': '710',
#   'age_adjusted_death_rate': '38.5'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New Hampshire',
#   'deaths': '329',
#   'age_adjusted_death_rate': '27.5'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New Jersey',
#   'deaths': '2,227',
#   'age_adjusted_death_rate': '26.2'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New Mexico',
#   'deaths': '969',
#   'age_adjusted_death_rate': '55.9'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'New York',
#   'deaths': '4,797',
#   'age_adjusted_death_rate': '25.2'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'North Carolina',
#   'deaths': '3,290',
#   'age_adjusted_death_rate': '42.1'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'North Dakota',
#   'deaths': '267',
#   'age_adjusted_death_rate': '38.4'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Ohio',
#   'deaths': '3,630',
#   'age_adjusted_death_rate': '31.8'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Oklahoma',
#   'deaths': '1,609',
#   'age_adjusted_death_rate': '46.3'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Oregon',
#   'deaths': '1,199',
#   'age_adjusted_death_rate': '34.7'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Pennsylvania',
#   'deaths': '4,614',
#   'age_adjusted_death_rate': '35.3'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Rhode Island',
#   'deaths': '243',
#   'age_adjusted_death_rate': '21.5'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'South Carolina',
#   'deaths': '1,901',
#   'age_adjusted_death_rate': '49.2'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'South Dakota',
#   'deaths': '351',
#   'age_adjusted_death_rate': '44.8'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Tennessee',
#   'deaths': '2,677',
#   'age_adjusted_death_rate': '47.8'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Texas',
#   'deaths': '7,227',
#   'age_adjusted_death_rate': '37.6'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'United States',
#   'deaths': '97,860',
#   'age_adjusted_death_rate': '35.3'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Utah',
#   'deaths': '650',
#   'age_adjusted_death_rate': '33.4'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Vermont',
#   'deaths': '209',
#   'age_adjusted_death_rate': '34.2'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Virginia',
#   'deaths': '2,214',
#   'age_adjusted_death_rate': '33.2'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Washington',
#   'deaths': '1,914',
#   'age_adjusted_death_rate': '33.3'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'West Virginia',
#   'deaths': '798',
#   'age_adjusted_death_rate': '42'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Wisconsin',
#   'deaths': '1,955',
#   'age_adjusted_death_rate': '35.6'},
#  {'year': '1999',
#   'cause': 'Accidents (unintentional injuries) (V01-X59,Y85-Y86)',
#   'cause_name': 'Unintentional injuries',
#   'state': 'Wyoming',
#   'deaths': '258',
#   'age_adjusted_death_rate': '52.8'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Alabama',
#   'deaths': '44,806',
#   'age_adjusted_death_rate': '1,009.30'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Alaska',
#   'deaths': '2,708',
#   'age_adjusted_death_rate': '838.9'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Arizona',
#   'deaths': '40,050',
#   'age_adjusted_death_rate': '818.4'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Arkansas',
#   'deaths': '27,925',
#   'age_adjusted_death_rate': '975.3'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'California',
#   'deaths': '229,380',
#   'age_adjusted_death_rate': '802.3'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Colorado',
#   'deaths': '27,114',
#   'age_adjusted_death_rate': '801.8'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Connecticut',
#   'deaths': '29,446',
#   'age_adjusted_death_rate': '783.2'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Delaware',
#   'deaths': '6,666',
#   'age_adjusted_death_rate': '881.6'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'District of Columbia',
#   'deaths': '6,076',
#   'age_adjusted_death_rate': '1,087.30'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Florida',
#   'deaths': '163,224',
#   'age_adjusted_death_rate': '812.8'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Georgia',
#   'deaths': '62,028',
#   'age_adjusted_death_rate': '964.9'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Hawaii',
#   'deaths': '8,270',
#   'age_adjusted_death_rate': '688.8'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Idaho',
#   'deaths': '9,579',
#   'age_adjusted_death_rate': '825.2'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Illinois',
#   'deaths': '108,436',
#   'age_adjusted_death_rate': '905.1'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Indiana',
#   'deaths': '55,303',
#   'age_adjusted_death_rate': '934.7'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Iowa',
#   'deaths': '28,411',
#   'age_adjusted_death_rate': '806.4'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Kansas',
#   'deaths': '24,472',
#   'age_adjusted_death_rate': '848.1'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Kentucky',
#   'deaths': '39,321',
#   'age_adjusted_death_rate': '1,004.10'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Louisiana',
#   'deaths': '41,238',
#   'age_adjusted_death_rate': '1,021.60'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Maine',
#   'deaths': '12,261',
#   'age_adjusted_death_rate': '865.9'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Maryland',
#   'deaths': '43,089',
#   'age_adjusted_death_rate': '907'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Massachusetts',
#   'deaths': '55,840',
#   'age_adjusted_death_rate': '814.1'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Michigan',
#   'deaths': '87,232',
#   'age_adjusted_death_rate': '916.4'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Minnesota',
#   'deaths': '38,537',
#   'age_adjusted_death_rate': '784.5'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Mississippi',
#   'deaths': '28,185',
#   'age_adjusted_death_rate': '1,043.40'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Missouri',
#   'deaths': '55,931',
#   'age_adjusted_death_rate': '945'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Nebraska',
#   'deaths': '15,579',
#   'age_adjusted_death_rate': '830.1'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Nevada',
#   'deaths': '15,082',
#   'age_adjusted_death_rate': '935.9'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New Hampshire',
#   'deaths': '9,537',
#   'age_adjusted_death_rate': '815.5'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New Jersey',
#   'deaths': '73,981',
#   'age_adjusted_death_rate': '853.7'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New Mexico',
#   'deaths': '13,676',
#   'age_adjusted_death_rate': '842.2'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'New York',
#   'deaths': '159,927',
#   'age_adjusted_death_rate': '833.4'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'North Carolina',
#   'deaths': '69,600',
#   'age_adjusted_death_rate': '933'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'North Dakota',
#   'deaths': '6,103',
#   'age_adjusted_death_rate': '796.8'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Ohio',
#   'deaths': '108,517',
#   'age_adjusted_death_rate': '934'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Oklahoma',
#   'deaths': '34,700',
#   'age_adjusted_death_rate': '979'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Oregon',
#   'deaths': '29,422',
#   'age_adjusted_death_rate': '837.6'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Pennsylvania',
#   'deaths': '130,283',
#   'age_adjusted_death_rate': '896.4'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Rhode Island',
#   'deaths': '9,708',
#   'age_adjusted_death_rate': '807.5'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'South Carolina',
#   'deaths': '36,053',
#   'age_adjusted_death_rate': '973.5'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'South Dakota',
#   'deaths': '6,953',
#   'age_adjusted_death_rate': '808.4'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Tennessee',
#   'deaths': '53,765',
#   'age_adjusted_death_rate': '980.4'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Texas',
#   'deaths': '146,858',
#   'age_adjusted_death_rate': '886.6'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'United States',
#   'deaths': '2,391,399',
#   'age_adjusted_death_rate': '875.6'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Utah',
#   'deaths': '12,058',
#   'age_adjusted_death_rate': '781.6'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Vermont',
#   'deaths': '4,993',
#   'age_adjusted_death_rate': '812.9'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Virginia',
#   'deaths': '55,320',
#   'age_adjusted_death_rate': '889.6'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Washington',
#   'deaths': '43,865',
#   'age_adjusted_death_rate': '815.1'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'West Virginia',
#   'deaths': '21,049',
#   'age_adjusted_death_rate': '1,012.30'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Wisconsin',
#   'deaths': '46,672',
#   'age_adjusted_death_rate': '831.5'},
#  {'year': '1999',
#   'cause': 'All Causes',
#   'cause_name': 'All causes',
#   'state': 'Wyoming',
#   'deaths': '4,042',
#   'age_adjusted_death_rate': '895.4'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Alabama',
#   'deaths': '772',
#   'age_adjusted_death_rate': '17.8'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Alaska',
#   'deaths': '24',
#   'age_adjusted_death_rate': '11.9'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Arizona',
#   'deaths': '963',
#   'age_adjusted_death_rate': '20.8'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Arkansas',
#   'deaths': '434',
#   'age_adjusted_death_rate': '14.8'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'California',
#   'deaths': '4,532',
#   'age_adjusted_death_rate': '16.6'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Colorado',
#   'deaths': '756',
#   'age_adjusted_death_rate': '24.5'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Connecticut',
#   'deaths': '449',
#   'age_adjusted_death_rate': '11.4'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Delaware',
#   'deaths': '107',
#   'age_adjusted_death_rate': '15'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'District of Columbia',
#   'deaths': '53',
#   'age_adjusted_death_rate': '9.5'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Florida',
#   'deaths': '3,059',
#   'age_adjusted_death_rate': '14.3'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Georgia',
#   'deaths': '1,080',
#   'age_adjusted_death_rate': '18.8'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Hawaii',
#   'deaths': '109',
#   'age_adjusted_death_rate': '9.4'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Idaho',
#   'deaths': '243',
#   'age_adjusted_death_rate': '21.4'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Illinois',
#   'deaths': '1,908',
#   'age_adjusted_death_rate': '15.9'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Indiana',
#   'deaths': '1,106',
#   'age_adjusted_death_rate': '18.9'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Iowa',
#   'deaths': '706',
#   'age_adjusted_death_rate': '18.2'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Kansas',
#   'deaths': '511',
#   'age_adjusted_death_rate': '16.6'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Kentucky',
#   'deaths': '728',
#   'age_adjusted_death_rate': '19.3'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Louisiana',
#   'deaths': '683',
#   'age_adjusted_death_rate': '17.9'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Maine',
#   'deaths': '429',
#   'age_adjusted_death_rate': '29.6'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Maryland',
#   'deaths': '681',
#   'age_adjusted_death_rate': '15.4'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Massachusetts',
#   'deaths': '1,182',
#   'age_adjusted_death_rate': '16.5'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Michigan',
#   'deaths': '1,431',
#   'age_adjusted_death_rate': '15.4'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Minnesota',
#   'deaths': '1,083',
#   'age_adjusted_death_rate': '21.1'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Mississippi',
#   'deaths': '356',
#   'age_adjusted_death_rate': '13.3'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Missouri',
#   'deaths': '914',
#   'age_adjusted_death_rate': '15'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Montana',
#   'deaths': '205',
#   'age_adjusted_death_rate': '21.4'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Nebraska',
#   'deaths': '331',
#   'age_adjusted_death_rate': '16.3'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Nevada',
#   'deaths': '174',
#   'age_adjusted_death_rate': '13.6'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New Hampshire',
#   'deaths': '266',
#   'age_adjusted_death_rate': '23.2'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New Jersey',
#   'deaths': '1,041',
#   'age_adjusted_death_rate': '12'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New Mexico',
#   'deaths': '248',
#   'age_adjusted_death_rate': '16.4'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'New York',
#   'deaths': '1,357',
#   'age_adjusted_death_rate': '7'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'North Carolina',
#   'deaths': '1,456',
#   'age_adjusted_death_rate': '20.8'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'North Dakota',
#   'deaths': '155',
#   'age_adjusted_death_rate': '18.1'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Ohio',
#   'deaths': '2,099',
#   'age_adjusted_death_rate': '18.2'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Oklahoma',
#   'deaths': '553',
#   'age_adjusted_death_rate': '15.4'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Oregon',
#   'deaths': '866',
#   'age_adjusted_death_rate': '24.1'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Pennsylvania',
#   'deaths': '2,192',
#   'age_adjusted_death_rate': '14.4'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Rhode Island',
#   'deaths': '219',
#   'age_adjusted_death_rate': '17'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'South Carolina',
#   'deaths': '690',
#   'age_adjusted_death_rate': '20.5'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'South Dakota',
#   'deaths': '155',
#   'age_adjusted_death_rate': '16.3'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Tennessee',
#   'deaths': '944',
#   'age_adjusted_death_rate': '17.9'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Texas',
#   'deaths': '2,833',
#   'age_adjusted_death_rate': '18.5'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'United States',
#   'deaths': '44,536',
#   'age_adjusted_death_rate': '16.5'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Utah',
#   'deaths': '245',
#   'age_adjusted_death_rate': '17.3'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Vermont',
#   'deaths': '127',
#   'age_adjusted_death_rate': '20.5'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Virginia',
#   'deaths': '917',
#   'age_adjusted_death_rate': '15.9'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Washington',
#   'deaths': '1,577',
#   'age_adjusted_death_rate': '29.8'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'West Virginia',
#   'deaths': '314',
#   'age_adjusted_death_rate': '15'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Wisconsin',
#   'deaths': '1,170',
#   'age_adjusted_death_rate': '19.9'},
#  {'year': '1999',
#   'cause': "Alzheimer's disease (G30)",
#   'cause_name': "Alzheimer's disease",
#   'state': 'Wyoming',
#   'deaths': '103',
#   'age_adjusted_death_rate': '23.9'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Alabama',
#   'deaths': '3,148',
#   'age_adjusted_death_rate': '71.5'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Alaska',
#   'deaths': '171',
#   'age_adjusted_death_rate': '71.2'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Arizona',
#   'deaths': '2,600',
#   'age_adjusted_death_rate': '54.4'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Arkansas',
#   'deaths': '2,255',
#   'age_adjusted_death_rate': '77.7'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'California',
#   'deaths': '17,962',
#   'age_adjusted_death_rate': '64.5'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Colorado',
#   'deaths': '1,834',
#   'age_adjusted_death_rate': '57.2'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Connecticut',
#   'deaths': '1,933',
#   'age_adjusted_death_rate': '50'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Delaware',
#   'deaths': '365',
#   'age_adjusted_death_rate': '49.4'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'District of Columbia',
#   'deaths': '297',
#   'age_adjusted_death_rate': '53.3'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Florida',
#   'deaths': '10,560',
#   'age_adjusted_death_rate': '50.5'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Georgia',
#   'deaths': '4,416',
#   'age_adjusted_death_rate': '72.3'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Hawaii',
#   'deaths': '762',
#   'age_adjusted_death_rate': '64.2'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Idaho',
#   'deaths': '771',
#   'age_adjusted_death_rate': '67.5'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Illinois',
#   'deaths': '7,714',
#   'age_adjusted_death_rate': '64.4'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Indiana',
#   'deaths': '4,057',
#   'age_adjusted_death_rate': '69'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Iowa',
#   'deaths': '2,317',
#   'age_adjusted_death_rate': '62.1'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Kansas',
#   'deaths': '1,841',
#   'age_adjusted_death_rate': '61.6'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Kentucky',
#   'deaths': '2,710',
#   'age_adjusted_death_rate': '70.4'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Louisiana',
#   'deaths': '2,684',
#   'age_adjusted_death_rate': '68.3'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Maine',
#   'deaths': '879',
#   'age_adjusted_death_rate': '61.2'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Maryland',
#   'deaths': '2,892',
#   'age_adjusted_death_rate': '63.3'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Massachusetts',
#   'deaths': '3,548',
#   'age_adjusted_death_rate': '50.4'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Michigan',
#   'deaths': '6,041',
#   'age_adjusted_death_rate': '64.3'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Minnesota',
#   'deaths': '2,997',
#   'age_adjusted_death_rate': '59.6'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Mississippi',
#   'deaths': '1,854',
#   'age_adjusted_death_rate': '69.2'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Missouri',
#   'deaths': '3,950',
#   'age_adjusted_death_rate': '65.6'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Montana',
#   'deaths': '595',
#   'age_adjusted_death_rate': '62.2'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Nebraska',
#   'deaths': '1,176',
#   'age_adjusted_death_rate': '60.2'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Nevada',
#   'deaths': '882',
#   'age_adjusted_death_rate': '59.4'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New Hampshire',
#   'deaths': '669',
#   'age_adjusted_death_rate': '57.9'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New Jersey',
#   'deaths': '4,122',
#   'age_adjusted_death_rate': '47.5'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New Mexico',
#   'deaths': '817',
#   'age_adjusted_death_rate': '52.5'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'New York',
#   'deaths': '8,124',
#   'age_adjusted_death_rate': '42.2'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'North Carolina',
#   'deaths': '5,626',
#   'age_adjusted_death_rate': '77.9'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'North Dakota',
#   'deaths': '513',
#   'age_adjusted_death_rate': '63'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Ohio',
#   'deaths': '7,235',
#   'age_adjusted_death_rate': '62.3'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Oklahoma',
#   'deaths': '2,481',
#   'age_adjusted_death_rate': '69.6'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Oregon',
#   'deaths': '2,799',
#   'age_adjusted_death_rate': '78.6'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Pennsylvania',
#   'deaths': '8,600',
#   'age_adjusted_death_rate': '57.5'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Rhode Island',
#   'deaths': '633',
#   'age_adjusted_death_rate': '50.4'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'South Carolina',
#   'deaths': '2,974',
#   'age_adjusted_death_rate': '83.4'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'South Dakota',
#   'deaths': '547',
#   'age_adjusted_death_rate': '60'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Tennessee',
#   'deaths': '4,103',
#   'age_adjusted_death_rate': '76.3'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Texas',
#   'deaths': '10,414',
#   'age_adjusted_death_rate': '65.9'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'United States',
#   'deaths': '167,366',
#   'age_adjusted_death_rate': '61.6'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Utah',
#   'deaths': '869',
#   'age_adjusted_death_rate': '60.2'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Vermont',
#   'deaths': '344',
#   'age_adjusted_death_rate': '55.8'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Virginia',
#   'deaths': '4,110',
#   'age_adjusted_death_rate': '68.7'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Washington',
#   'deaths': '3,718',
#   'age_adjusted_death_rate': '69.9'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'West Virginia',
#   'deaths': '1,323',
#   'age_adjusted_death_rate': '63.1'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Wisconsin',
#   'deaths': '3,869',
#   'age_adjusted_death_rate': '67.5'},
#  {'year': '1999',
#   'cause': 'Cerebrovascular diseases (I60-I69)',
#   'cause_name': 'Stroke',
#   'state': 'Wyoming',
#   'deaths': '265',
#   'age_adjusted_death_rate': '60.7'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Alabama',
#   'deaths': '2,179',
#   'age_adjusted_death_rate': '48.6'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Alaska',
#   'deaths': '146',
#   'age_adjusted_death_rate': '56.4'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Arizona',
#   'deaths': '2,553',
#   'age_adjusted_death_rate': '51.2'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Arkansas',
#   'deaths': '1,358',
#   'age_adjusted_death_rate': '46.8'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'California',
#   'deaths': '13,165',
#   'age_adjusted_death_rate': '46.9'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Colorado',
#   'deaths': '1,894',
#   'age_adjusted_death_rate': '58.1'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Connecticut',
#   'deaths': '1,435',
#   'age_adjusted_death_rate': '37.8'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Delaware',
#   'deaths': '327',
#   'age_adjusted_death_rate': '42.7'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'District of Columbia',
#   'deaths': '166',
#   'age_adjusted_death_rate': '29.9'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Florida',
#   'deaths': '9,131',
#   'age_adjusted_death_rate': '43.1'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Georgia',
#   'deaths': '3,056',
#   'age_adjusted_death_rate': '49.1'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Hawaii',
#   'deaths': '290',
#   'age_adjusted_death_rate': '24'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Idaho',
#   'deaths': '568',
#   'age_adjusted_death_rate': '49.5'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Illinois',
#   'deaths': '5,155',
#   'age_adjusted_death_rate': '43.2'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Indiana',
#   'deaths': '3,053',
#   'age_adjusted_death_rate': '51.6'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Iowa',
#   'deaths': '1,643',
#   'age_adjusted_death_rate': '46.8'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Kansas',
#   'deaths': '1,386',
#   'age_adjusted_death_rate': '48.7'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Kentucky',
#   'deaths': '2,327',
#   'age_adjusted_death_rate': '59'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Louisiana',
#   'deaths': '1,610',
#   'age_adjusted_death_rate': '40.2'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Maine',
#   'deaths': '751',
#   'age_adjusted_death_rate': '52.6'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Maryland',
#   'deaths': '1,943',
#   'age_adjusted_death_rate': '41.6'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Massachusetts',
#   'deaths': '2,862',
#   'age_adjusted_death_rate': '41.6'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Michigan',
#   'deaths': '4,316',
#   'age_adjusted_death_rate': '45.3'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Minnesota',
#   'deaths': '1,994',
#   'age_adjusted_death_rate': '41.3'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Mississippi',
#   'deaths': '1,267',
#   'age_adjusted_death_rate': '47.2'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Missouri',
#   'deaths': '3,068',
#   'age_adjusted_death_rate': '51.7'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Montana',
#   'deaths': '566',
#   'age_adjusted_death_rate': '59.4'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Nebraska',
#   'deaths': '945',
#   'age_adjusted_death_rate': '50.6'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Nevada',
#   'deaths': '1,029',
#   'age_adjusted_death_rate': '64.7'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New Hampshire',
#   'deaths': '592',
#   'age_adjusted_death_rate': '51'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New Jersey',
#   'deaths': '3,130',
#   'age_adjusted_death_rate': '35.9'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New Mexico',
#   'deaths': '848',
#   'age_adjusted_death_rate': '52.9'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'New York',
#   'deaths': '7,086',
#   'age_adjusted_death_rate': '36.9'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'North Carolina',
#   'deaths': '3,591',
#   'age_adjusted_death_rate': '48'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'North Dakota',
#   'deaths': '273',
#   'age_adjusted_death_rate': '35.8'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Ohio',
#   'deaths': '5,858',
#   'age_adjusted_death_rate': '49.9'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Oklahoma',
#   'deaths': '1,751',
#   'age_adjusted_death_rate': '49.3'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Oregon',
#   'deaths': '1,765',
#   'age_adjusted_death_rate': '50.4'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Pennsylvania',
#   'deaths': '6,141',
#   'age_adjusted_death_rate': '41.1'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Rhode Island',
#   'deaths': '495',
#   'age_adjusted_death_rate': '40.6'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'South Carolina',
#   'deaths': '1,752',
#   'age_adjusted_death_rate': '47'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'South Dakota',
#   'deaths': '335',
#   'age_adjusted_death_rate': '38.6'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Tennessee',
#   'deaths': '2,748',
#   'age_adjusted_death_rate': '49.9'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Texas',
#   'deaths': '7,518',
#   'age_adjusted_death_rate': '46.8'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'United States',
#   'deaths': '124,181',
#   'age_adjusted_death_rate': '45.4'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Utah',
#   'deaths': '559',
#   'age_adjusted_death_rate': '37.6'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Vermont',
#   'deaths': '300',
#   'age_adjusted_death_rate': '49.2'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Virginia',
#   'deaths': '2,699',
#   'age_adjusted_death_rate': '43.8'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Washington',
#   'deaths': '2,713',
#   'age_adjusted_death_rate': '51.2'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'West Virginia',
#   'deaths': '1,236',
#   'age_adjusted_death_rate': '57.9'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Wisconsin',
#   'deaths': '2,270',
#   'age_adjusted_death_rate': '40.5'},
#  {'year': '1999',
#   'cause': 'Chronic lower respiratory diseases (J40-J47)',
#   'cause_name': 'CLRD',
#   'state': 'Wyoming',
#   'deaths': '338',
#   'age_adjusted_death_rate': '75.6'},
#  {'year': '1999',
#   'cause': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Alabama',
#   'deaths': '1,341',
#   'age_adjusted_death_rate': '30'},
#  {'year': '1999',
#   'cause': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Alaska',
#   'deaths': '67',
#   'age_adjusted_death_rate': '23.8'},
#  {'year': '1999',
#   'cause': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Arizona',
#   'deaths': '1,063',
#   'age_adjusted_death_rate': '21.5'},
#  {'year': '1999',
#   'cause': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Arkansas',
#   'deaths': '691',
#   'age_adjusted_death_rate': '24.2'},
#  {'year': '1999',
#   'cause': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'California',
#   'deaths': '6,401',
#   'age_adjusted_death_rate': '22.5'},
#  {'year': '1999',
#   'cause': 'Diabetes mellitus (E10-E14)',
#   'cause_name': 'Diabetes',
#   'state': 'Colorado',
#   'deaths': '639',
#   'age_adjusted_death_rate': '19.2'},
#  {'year': '1999',
# ...
#   'state': 'New York',
#   'deaths': '57,474',
#   'age_adjusted_death_rate': '293.8'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'North Carolina',
#   'deaths': '19,723',
#   'age_adjusted_death_rate': '264.5'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'North Dakota',
#   'deaths': '1,679',
#   'age_adjusted_death_rate': '212.8'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Ohio',
#   'deaths': '32,722',
#   'age_adjusted_death_rate': '279.2'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Oklahoma',
#   'deaths': '11,297',
#   'age_adjusted_death_rate': '315'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Oregon',
#   'deaths': '7,094',
#   'age_adjusted_death_rate': '198.1'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Pennsylvania',
#   'deaths': '40,708',
#   'age_adjusted_death_rate': '271.9'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Rhode Island',
#   'deaths': '3,115',
#   'age_adjusted_death_rate': '249.5'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'South Carolina',
#   'deaths': '9,893',
#   'age_adjusted_death_rate': '265.8'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'South Dakota',
#   'deaths': '2,105',
#   'age_adjusted_death_rate': '234.5'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Tennessee',
#   'deaths': '16,174',
#   'age_adjusted_death_rate': '293.6'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Texas',
#   'deaths': '43,020',
#   'age_adjusted_death_rate': '263.5'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'United States',
#   'deaths': '710,760',
#   'age_adjusted_death_rate': '257.6'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Utah',
#   'deaths': '2,909',
#   'age_adjusted_death_rate': '194'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Vermont',
#   'deaths': '1,438',
#   'age_adjusted_death_rate': '229.4'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Virginia',
#   'deaths': '15,264',
#   'age_adjusted_death_rate': '245.5'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Washington',
#   'deaths': '11,370',
#   'age_adjusted_death_rate': '209.7'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'West Virginia',
#   'deaths': '6,435',
#   'age_adjusted_death_rate': '305'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Wisconsin',
#   'deaths': '13,601',
#   'age_adjusted_death_rate': '237.3'},
#  {'year': '2000',
#   'cause': 'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#   'cause_name': 'Heart disease',
#   'state': 'Wyoming',
#   'deaths': '992',
#   'age_adjusted_death_rate': '217.4'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Alabama',
#   'deaths': '1,138',
#   'age_adjusted_death_rate': '25.7'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Alaska',
#   'deaths': '45',
#   'age_adjusted_death_rate': '16'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Arizona',
#   'deaths': '1,222',
#   'age_adjusted_death_rate': '25.2'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Arkansas',
#   'deaths': '798',
#   'age_adjusted_death_rate': '27.2'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'California',
#   'deaths': '8,324',
#   'age_adjusted_death_rate': '29.5'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Colorado',
#   'deaths': '607',
#   'age_adjusted_death_rate': '18.6'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Connecticut',
#   'deaths': '890',
#   'age_adjusted_death_rate': '22.5'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Delaware',
#   'deaths': '229',
#   'age_adjusted_death_rate': '31'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'District of Columbia',
#   'deaths': '111',
#   'age_adjusted_death_rate': '19.6'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Florida',
#   'deaths': '3,365',
#   'age_adjusted_death_rate': '16'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Georgia',
#   'deaths': '1,792',
#   'age_adjusted_death_rate': '29.4'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Hawaii',
#   'deaths': '221',
#   'age_adjusted_death_rate': '18.2'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Idaho',
#   'deaths': '288',
#   'age_adjusted_death_rate': '24.6'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Illinois',
#   'deaths': '2,917',
#   'age_adjusted_death_rate': '24'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Indiana',
#   'deaths': '1,270',
#   'age_adjusted_death_rate': '21.4'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Iowa',
#   'deaths': '937',
#   'age_adjusted_death_rate': '24.8'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Kansas',
#   'deaths': '743',
#   'age_adjusted_death_rate': '24.2'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Kentucky',
#   'deaths': '1,157',
#   'age_adjusted_death_rate': '29.9'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Louisiana',
#   'deaths': '972',
#   'age_adjusted_death_rate': '24.7'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Maine',
#   'deaths': '336',
#   'age_adjusted_death_rate': '22.9'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Maryland',
#   'deaths': '1,116',
#   'age_adjusted_death_rate': '24'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Massachusetts',
#   'deaths': '2,078',
#   'age_adjusted_death_rate': '28.9'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Michigan',
#   'deaths': '2,052',
#   'age_adjusted_death_rate': '21.6'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Minnesota',
#   'deaths': '845',
#   'age_adjusted_death_rate': '16.4'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Mississippi',
#   'deaths': '809',
#   'age_adjusted_death_rate': '29.8'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Missouri',
#   'deaths': '1,629',
#   'age_adjusted_death_rate': '26.7'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Montana',
#   'deaths': '202',
#   'age_adjusted_death_rate': '20.9'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Nebraska',
#   'deaths': '433',
#   'age_adjusted_death_rate': '21.8'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Nevada',
#   'deaths': '320',
#   'age_adjusted_death_rate': '21.5'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New Hampshire',
#   'deaths': '194',
#   'age_adjusted_death_rate': '16.5'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New Jersey',
#   'deaths': '2,044',
#   'age_adjusted_death_rate': '23.2'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New Mexico',
#   'deaths': '290',
#   'age_adjusted_death_rate': '18.2'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'New York',
#   'deaths': '5,201',
#   'age_adjusted_death_rate': '26.5'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'North Carolina',
#   'deaths': '1,945',
#   'age_adjusted_death_rate': '26.8'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'North Dakota',
#   'deaths': '166',
#   'age_adjusted_death_rate': '19.8'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Ohio',
#   'deaths': '2,533',
#   'age_adjusted_death_rate': '21.7'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Oklahoma',
#   'deaths': '885',
#   'age_adjusted_death_rate': '24.6'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Oregon',
#   'deaths': '642',
#   'age_adjusted_death_rate': '17.8'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Pennsylvania',
#   'deaths': '3,069',
#   'age_adjusted_death_rate': '20.3'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Rhode Island',
#   'deaths': '342',
#   'age_adjusted_death_rate': '26.6'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'South Carolina',
#   'deaths': '699',
#   'age_adjusted_death_rate': '19.5'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'South Dakota',
#   'deaths': '212',
#   'age_adjusted_death_rate': '22.7'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Tennessee',
#   'deaths': '1,672',
#   'age_adjusted_death_rate': '30.9'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Texas',
#   'deaths': '3,706',
#   'age_adjusted_death_rate': '23.1'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'United States',
#   'deaths': '65,313',
#   'age_adjusted_death_rate': '23.7'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Utah',
#   'deaths': '388',
#   'age_adjusted_death_rate': '26.1'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Vermont',
#   'deaths': '119',
#   'age_adjusted_death_rate': '19'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Virginia',
#   'deaths': '1,510',
#   'age_adjusted_death_rate': '25.1'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Washington',
#   'deaths': '1,010',
#   'age_adjusted_death_rate': '18.7'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'West Virginia',
#   'deaths': '456',
#   'age_adjusted_death_rate': '21.7'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Wisconsin',
#   'deaths': '1,258',
#   'age_adjusted_death_rate': '21.5'},
#  {'year': '2000',
#   'cause': 'Influenza and pneumonia (J09-J18)',
#   'cause_name': 'Influenza and pneumonia',
#   'state': 'Wyoming',
#   'deaths': '126',
#   'age_adjusted_death_rate': '28.3'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Alabama',
#   'deaths': '583',
#   'age_adjusted_death_rate': '13.1'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Alaska',
#   'deaths': '137',
#   'age_adjusted_death_rate': '21.5'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Arizona',
#   'deaths': '784',
#   'age_adjusted_death_rate': '15.6'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Arkansas',
#   'deaths': '349',
#   'age_adjusted_death_rate': '13'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'California',
#   'deaths': '2,969',
#   'age_adjusted_death_rate': '9.1'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Colorado',
#   'deaths': '613',
#   'age_adjusted_death_rate': '14.3'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Connecticut',
#   'deaths': '304',
#   'age_adjusted_death_rate': '8.8'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Delaware',
#   'deaths': '82',
#   'age_adjusted_death_rate': '10.4'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'District of Columbia',
#   'deaths': '23',
#   'age_adjusted_death_rate': '3.8'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Florida',
#   'deaths': '2,086',
#   'age_adjusted_death_rate': '12.4'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Georgia',
#   'deaths': '847',
#   'age_adjusted_death_rate': '10.7'},
#  {'year': '2000',
#   'cause': 'Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)',
#   'cause_name': 'Suicide',
#   'state': 'Hawaii',
#   'deaths': '137',
#   'age_adjusted_death_rate': '11.2'},
#  ...]
