# %%
# Ignore SQLITE warnings related to Decimal numbers in the Chinook database
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
from collections import OrderedDict
import pandas as pd 
import collections
import json

# %%
import pandas as pd
import matplotlib.pyplot as plt
from config import USER, PASSWORD, ADDRESS, PORT, DATABASE
from sqlalchemy import create_engine
connection_string = (f'postgresql://{USER}:{PASSWORD}@{ADDRESS}:{PORT}/{DATABASE}')

# %%
engine = create_engine(connection_string)
cn = engine.connect()

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['cdc_death_table']

# %%
deaths=Base.classes.cdc_death_table

# %%
session = Session(engine)

# %%
deaths_dt=session.query(deaths.sex).all()[0]
deaths_dt
# Out:
# ('F')

# %%
data = session.query(deaths).all()
load = []
content = {}
for result in data:
        content = {'year': result.year, 
                   'cause': result.cause, 
                   'cause_name': result.cause_name,
                   'state': result.state,
                   'deaths': result.deaths,
                   'age_adjusted-death_rate': result.age_adjusted-death_rate
                  }
                  
        
        
        load.append(content)
        content = {}
load
# Out:
# [{'id': 8590139454,
#   'education': 6,
#   'sex': 'M',
#   'age': 61,
#   'race': 1,
#   'hispanic': 6,
#   'marital_status': 'M',
#   'month_of_death:': 4,
#   'day_of_week_of_death': 7,
#   'current_data_year': 2015,
#   'manner_of_death': 7,
#   'injury_at_work': 'U',
#   'icd_death_code': 'I249',
#   'entity_condition_1': '11I249',
#   'entity_condition_2': '61I500',
#   'entity_condition_3': '62I10'},
#  {'id': 8590139455,
#   'education': 4,
#   'sex': 'M',
#   'age': 48,
#   'race': 1,
#   'hispanic': 6,
#   'marital_status': 'S',
#   'month_of_death:': 4,
#   'day_of_week_of_death': 7,
#   'current_data_year': 2015,
#   'manner_of_death': 7,
#   'injury_at_work': 'U',
#   'icd_death_code': 'K746',
#   'entity_condition_1': '11K746',
#   'entity_condition_2': '0',
#   'entity_condition_3': '0'},
#  {'id': 8590139456,
#   'education': 4,
#   'sex': 'F',
#   'age': 43,
#   'race': 1,
#   'hispanic': 6,
#   'marital_status': 'D',
#   'month_of_death:': 4,
# ...
